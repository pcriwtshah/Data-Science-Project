# %%
# Import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt; 
plt.style.use('seaborn-whitegrid')
import seaborn as sns
from datetime import date
print('Set up Complete')
# Out:
# Set up Complete

# %%
# Load data
accidents = pd.read_csv('dft-road-casualty-statistics-accident-2020.csv')
accidents.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (0,2) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   accident_index  accident_year accident_reference  location_easting_osgr  \
# 0  2020010219808           2020           10219808               521389.0
# 1  2020010220496           2020           10220496               529337.0
# 2  2020010228005           2020           10228005               526432.0
# 3  2020010228006           2020           10228006               538676.0
# 4  2020010228011           2020           10228011               529324.0
#
#    location_northing_osgr  longitude   latitude  police_force  \
# 0                175144.0  -0.254001  51.462262             1
# 1                176237.0  -0.139253  51.470327             1
# 2                182761.0  -0.178719  51.529614             1
# ...

# %%
accidents.info
# Out:
# <bound method DataFrame.info of       accident_index  accident_year accident_reference  location_easting_osgr  \
# 0      2020010219808           2020           10219808               521389.0
# 1      2020010220496           2020           10220496               529337.0
# 2      2020010228005           2020           10228005               526432.0
# 3      2020010228006           2020           10228006               538676.0
# 4      2020010228011           2020           10228011               529324.0
# ...              ...            ...                ...                    ...
# 91194  2020991027064           2020          991027064               343034.0
# 91195  2020991029573           2020          991029573               257963.0
# 91196  2020991030297           2020          991030297               383664.0
# 91197  2020991030900           2020          991030900               277161.0
# 91198  2020991032575           2020          991032575               240402.0
#
# ...

# %%
accidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91199 entries, 0 to 91198
# Data columns (total 36 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   accident_index                               91199 non-null  object
#  1   accident_year                                91199 non-null  int64
#  2   accident_reference                           91199 non-null  object
#  3   location_easting_osgr                        91185 non-null  float64
#  4   location_northing_osgr                       91185 non-null  float64
#  5   longitude                                    91185 non-null  float64
#  6   latitude                                     91185 non-null  float64
#  7   police_force                                 91199 non-null  int64
#  8   accident_severity                            91199 non-null  int64
# ...

# %%
#Check if all data are from same year or different year
accidents.accident_year.unique()
# Out:
# array([2020])

# %%
#Drop the columns on which no operation will be done.
accidents.drop(['accident_index', 'accident_year', 'accident_reference'], axis = 1, inplace = True)

# %%
accidents.head()
# Out:
#    location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 0               521389.0                175144.0  -0.254001  51.462262
# 1               529337.0                176237.0  -0.139253  51.470327
# 2               526432.0                182761.0  -0.178719  51.529614
# 3               538676.0                184371.0  -0.001683  51.541210
# 4               529324.0                181286.0  -0.137592  51.515704
#
#    police_force  accident_severity  number_of_vehicles  number_of_casualties  \
# 0             1                  3                   1                     1
# 1             1                  3                   1                     2
# 2             1                  3                   1                     1
# 3             1                  2                   1                     1
# 4             1                  3                   1                     2
#
#          date  day_of_week  ... pedestrian_crossing_physical_facilities  \
# ...

# %%
#See which rows have missing values along with other info.
accidents[accidents.isnull().any(axis=1)]
# Out:
#        location_easting_osgr  location_northing_osgr  longitude  latitude  \
# 25520                    NaN                     NaN        NaN       NaN
# 29452                    NaN                     NaN        NaN       NaN
# 32689                    NaN                     NaN        NaN       NaN
# 33578                    NaN                     NaN        NaN       NaN
# 81252                    NaN                     NaN        NaN       NaN
# 86437                    NaN                     NaN        NaN       NaN
# 86642                    NaN                     NaN        NaN       NaN
# 86651                    NaN                     NaN        NaN       NaN
# 86668                    NaN                     NaN        NaN       NaN
# 86705                    NaN                     NaN        NaN       NaN
# 86785                    NaN                     NaN        NaN       NaN
# 87018                    NaN                     NaN        NaN       NaN
# ...

# %%
#Check if there are any missing values in data
#accidents.isnull().values.any()

# %%
#Check how many missing values are there in each column.
accidents.isnull().sum()
# Out:
# location_easting_osgr                          14
# location_northing_osgr                         14
# longitude                                      14
# latitude                                       14
# police_force                                    0
# accident_severity                               0
# number_of_vehicles                              0
# number_of_casualties                            0
# date                                            0
# day_of_week                                     0
# time                                            0
# local_authority_district                        0
# local_authority_ons_district                    0
# local_authority_highway                         0
# first_road_class                                0
# first_road_number                               0
# road_type                                       0
# speed_limit                                     0
# junction_detail                                 0
# ...

# %%
#Check the shape (# of rows and # of columns) in  a data
accidents.shape
# Out:
# (91199, 33)

# %%
#Check the data types of each column
accidents.dtypes
# Out:
# location_easting_osgr                          float64
# location_northing_osgr                         float64
# longitude                                      float64
# latitude                                       float64
# police_force                                     int64
# accident_severity                                int64
# number_of_vehicles                               int64
# number_of_casualties                             int64
# date                                            object
# day_of_week                                      int64
# time                                            object
# local_authority_district                         int64
# local_authority_ons_district                    object
# local_authority_highway                         object
# first_road_class                                 int64
# first_road_number                                int64
# road_type                                        int64
# ...

# %%
#Check if there is any duplicates
accidents.duplicated().any()
# Out:
# True

# %%
#Check how many duplicates 
accidents.duplicated().sum()
# Out:
# 1

# %%
accidents.duplicated(keep = False)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 91194    False
# 91195    False
# 91196    False
# 91197    False
# 91198    False
# Length: 91199, dtype: bool

# %% [markdown]
# # Boxplot

# %%
sns.boxplot(data = accidents.number_of_casualties)
# Out:
# <AxesSubplot:>

# %%
accidents[['date', 'day_of_week', 'time', 'speed_limit']].head()
# Out:
#          date  day_of_week   time  speed_limit
# 0  04/02/2020            3  09:00           20
# 1  27/04/2020            2  13:55           20
# 2  01/01/2020            4  01:25           30
# 3  01/01/2020            4  01:50           30
# 4  01/01/2020            4  02:25           30

# %%
sns.boxplot(x = accidents.speed_limit, y = accidents.number_of_casualties)
# Out:
# <AxesSubplot:xlabel='speed_limit', ylabel='number_of_casualties'>

# %%
sns.barplot(x = accidents.speed_limit, y = accidents.number_of_casualties)
# Out:
# <AxesSubplot:xlabel='speed_limit', ylabel='number_of_casualties'>

# %%
#Count the number of casualties
sns.countplot(x="number_of_casualties", data=accidents)
# Out:
# <AxesSubplot:xlabel='number_of_casualties', ylabel='count'>

# %%
sns.countplot(x="speed_limit", data=accidents)
# Out:
# <AxesSubplot:xlabel='speed_limit', ylabel='count'>

# %%
sns.boxplot(x = 'day_of_week', y="number_of_casualties", data=accidents, hue= 'speed_limit')
# Out:
# <AxesSubplot:xlabel='day_of_week', ylabel='number_of_casualties'>

# %%
sns.relplot(x = 'day_of_week', y="accident_severity", data=accidents) # hue= 'speed_limit')

# %%
sns.relplot(x="latitude", y="longitude", data=accidents)

# %%
sns.relplot(x="speed_limit", y="accident_severity", data=accidents)

# %%
#Add a column "major_incident"
accidents['major_incident'] = [1 if (i==1)&(j>=3) else 0 \
                               for i, j in zip(accidents['accident_severity'], \
                                               accidents['number_of_casualties'])]

# %%
accidents.describe()
# Out:
#        location_easting_osgr  location_northing_osgr     longitude  \
# count           91185.000000            9.118500e+04  91185.000000
# mean           456487.876416            2.737645e+05     -1.189258
# std             93512.711807            1.473516e+05      1.367786
# min             65947.000000            1.271500e+04     -7.497375
# 25%            392890.000000            1.745690e+05     -2.107789
# 50%            465545.000000            2.085990e+05     -1.046912
# 75%            530168.000000            3.783660e+05     -0.125238
# max            655138.000000            1.184351e+06      1.756257
#
#            latitude  police_force  accident_severity  number_of_vehicles  \
# count  91185.000000  91199.000000       91199.000000        91199.000000
# mean      52.351073     27.488043           2.768232            1.835272
# std        1.327573     24.548964           0.456682            0.677272
# ...

# %%
#Create a subset of data for certain columns
accident_sub=accidents[['police_force', 'accident_severity', 'number_of_vehicles', 'number_of_casualties', 'day_of_week','time','major_incident']]

# %%
accident_sub
# Out:
#        police_force  accident_severity  number_of_vehicles  \
# 0                 1                  3                   1
# 1                 1                  3                   1
# 2                 1                  3                   1
# 3                 1                  2                   1
# 4                 1                  3                   1
# ...             ...                ...                 ...
# 91194            99                  2                   2
# 91195            99                  3                   1
# 91196            99                  2                   2
# 91197            99                  3                   2
# 91198            99                  3                   1
#
#        number_of_casualties  day_of_week   time  major_incident
# 0                         1            3  09:00               0
# 1                         2            2  13:55               0
# ...

# %%
#Plot the graph
# Set the width and height of the figure
plt.figure(figsize=(18,10))

#Bar Chart showing number of casualties on different day of the week
sns.barplot(x=accident_sub['day_of_week'], y=accident_sub['number_of_casualties'])
# Out:
# <AxesSubplot:xlabel='day_of_week', ylabel='number_of_casualties'>

# %%
# Set the width and height of the figure
plt.figure(figsize=(18,10))
#Bar Chart showing number of casualties on different day of the week
sns.barplot(x=accident_sub['day_of_week'], y=accident_sub['police_force'])
# Out:
# <AxesSubplot:xlabel='day_of_week', ylabel='police_force'>
