# %%
import yfinance as yf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-7b70635dcb62> in <module>()
# ----> 1 import yfinance as yf
#
# ModuleNotFoundError: No module named 'yfinance'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip3 install yfinance
# Out:
# ...
#      |████████████████████████████████| 63 kB 1.4 MB/s
# ...
#      |████████████████████████████████| 6.4 MB 41.7 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# ...

# %%
import yfinance as yf

# %%
tick = "FB"

# %%
yf.download(tick)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High  ...   Adj Close     Volume
# Date                                ...
# 2012-05-18   42.049999   45.000000  ...   38.230000  573576400
# 2012-05-21   36.529999   36.660000  ...   34.029999  168192700
# 2012-05-22   32.610001   33.590000  ...   31.000000  101786600
# 2012-05-23   31.370001   32.500000  ...   32.000000   73600000
# 2012-05-24   32.950001   33.209999  ...   33.029999   50237200
# ...                ...         ...  ...         ...        ...
# 2021-12-29  346.910004  349.690002  ...  342.940002   10747000
# 2021-12-30  344.000000  347.230011  ...  344.359985   10593300
# 2021-12-31  343.019989  343.440002  ...  336.350006   12854800
# 2022-01-03  338.299988  341.079987  ...  338.540009   14537900
# 2022-01-04  339.950012  343.089996  ...  336.529999   15989000
#
# [2424 rows x 6 columns]

# %%
fb = yf.download(tick)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
fb.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2012-05-18  42.049999  45.000000  38.000000  38.230000  38.230000  573576400
# 2012-05-21  36.529999  36.660000  33.000000  34.029999  34.029999  168192700
# 2012-05-22  32.610001  33.590000  30.940001  31.000000  31.000000  101786600
# 2012-05-23  31.370001  32.500000  31.360001  32.000000  32.000000   73600000
# 2012-05-24  32.950001  33.209999  31.770000  33.029999  33.029999   50237200

# %%
fb.tail()
# Out:
#                   Open        High  ...   Adj Close    Volume
# Date                                ...
# 2021-12-29  346.910004  349.690002  ...  342.940002  10747000
# 2021-12-30  344.000000  347.230011  ...  344.359985  10593300
# 2021-12-31  343.019989  343.440002  ...  336.350006  12854800
# 2022-01-03  338.299988  341.079987  ...  338.540009  14537900
# 2022-01-04  339.950012  343.089996  ...  336.529999  15989000
#
# [5 rows x 6 columns]

# %%
fb = yf.download(tick, start = "2021-1-1", end="2021-12-31", rounding = True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
fb.head()
# Out:
#               Open    High     Low   Close  Adj Close    Volume
# Date
# 2021-01-04  274.78  275.00  265.20  268.94     268.94  15106100
# 2021-01-05  268.29  272.40  268.21  270.97     270.97   9871600
# 2021-01-06  262.00  267.75  260.01  263.31     263.31  24354100
# 2021-01-07  265.90  271.61  264.78  268.74     268.74  15789800
# 2021-01-08  268.31  268.95  263.18  267.57     267.57  18528300

# %%
yf.download(tick, start = "2021-1-1", end="2021-12-31", rounding = True)["Adj Close"]
# Out:
# [*********************100%***********************]  1 of 1 completed
# Date
# 2021-01-04    268.94
# 2021-01-05    270.97
# 2021-01-06    263.31
# 2021-01-07    268.74
# 2021-01-08    267.57
#                ...
# 2021-12-23    335.24
# 2021-12-27    346.18
# 2021-12-28    346.22
# 2021-12-29    342.94
# 2021-12-30    344.36
# Name: Adj Close, Length: 251, dtype: float64

# %%
ticks = ["FB", "AMZN", "MSFT", "AAPL"]

# %%
yf.download(ticks, start = "2021-1-1", end="2021-12-31", rounding = True)
# Out:
# [*********************100%***********************]  4 of 4 completed
#            Adj Close                   ...   Volume
#                 AAPL     AMZN      FB  ...     AMZN        FB      MSFT
# Date                                   ...
# 2021-01-04    128.62  3186.63  268.94  ...  4411400  15106100  37130100
# 2021-01-05    130.21  3218.51  270.97  ...  2655500   9871600  23823000
# 2021-01-06    125.82  3138.38  263.31  ...  4394800  24354100  35930700
# 2021-01-07    130.12  3162.16  268.74  ...  3514500  15789800  27694500
# 2021-01-08    131.24  3182.70  267.57  ...  3537700  18528300  22956200
# ...              ...      ...     ...  ...      ...       ...       ...
# 2021-12-23    176.28  3421.37  335.24  ...  1839400  13987700  19617800
# 2021-12-27    180.33  3393.39  346.18  ...  2934400  17795000  19947000
# 2021-12-28    179.29  3413.22  346.22  ...  2731900  16637600  15661500
# 2021-12-29    179.38  3384.02  342.94  ...  1787700  10747000  15042000
# ...

# %%
yf.download(ticks, start = "2021-1-1", end="2021-12-31", rounding = True, group_by = 'ticker')
# Out:
# [*********************100%***********************]  4 of 4 completed
#                 FB                          ...     AMZN
#               Open    High     Low   Close  ...      Low    Close Adj Close   Volume
# Date                                        ...
# 2021-01-04  274.78  275.00  265.20  268.94  ...  3144.02  3186.63   3186.63  4411400
# 2021-01-05  268.29  272.40  268.21  270.97  ...  3165.06  3218.51   3218.51  2655500
# 2021-01-06  262.00  267.75  260.01  263.31  ...  3131.16  3138.38   3138.38  4394800
# 2021-01-07  265.90  271.61  264.78  268.74  ...  3155.00  3162.16   3162.16  3514500
# 2021-01-08  268.31  268.95  263.18  267.57  ...  3142.20  3182.70   3182.70  3537700
# ...            ...     ...     ...     ...  ...      ...      ...       ...      ...
# 2021-12-23  330.10  336.67  328.36  335.24  ...  3403.00  3421.37   3421.37  1839400
# 2021-12-27  338.85  347.87  338.01  346.18  ...  3384.31  3393.39   3393.39  2934400
# ...

# %%
yf.download(ticks, start = "2021-1-1", end="2021-12-31", rounding = True)["Adj Close"] #no group_by here
# Out:
# [*********************100%***********************]  4 of 4 completed
#               AAPL     AMZN      FB    MSFT
# Date
# 2021-01-04  128.62  3186.63  268.94  215.88
# 2021-01-05  130.21  3218.51  270.97  216.09
# 2021-01-06  125.82  3138.38  263.31  210.49
# 2021-01-07  130.12  3162.16  268.74  216.48
# 2021-01-08  131.24  3182.70  267.57  217.79
# ...            ...      ...     ...     ...
# 2021-12-23  176.28  3421.37  335.24  334.69
# 2021-12-27  180.33  3393.39  346.18  342.45
# 2021-12-28  179.29  3413.22  346.22  341.25
# 2021-12-29  179.38  3384.02  342.94  341.95
# 2021-12-30  178.20  3372.89  344.36  339.32
#
# [251 rows x 4 columns]

# %%
type(yf.download(ticks, start = "2021-1-1", end="2021-12-31", rounding = True)["Adj Close"])
# Out:
# [*********************100%***********************]  4 of 4 completed
# pandas.core.frame.DataFrame

# %%
type(yf.download(ticks, start = "2021-1-1", end="2021-12-31", rounding = True)["Adj Close"]["AAPL"])
# Out:
# [*********************100%***********************]  4 of 4 completed
# pandas.core.series.Series

# %% [markdown]
# Other way to import yahoo finance data is by using panda

# %%
import pandas as pd

# %%
url_options = 'https://finance.yahoo.com/quote/AAPL/history?p=AAPL'

# %%
url_financials = 'https://finance.yahoo.com/quote/AAPL/financials?p=AAPL'

# %%
options_tables = pd.read_html(url_financials)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-53-3d25ea05d936> in <module>()
# ----> 1 options_tables = pd.read_html(url_financials)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1099         na_values=na_values,
#    1100         keep_default_na=keep_default_na,
# -> 1101         displayed_only=displayed_only,
#    1102     )
#
# ...

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/Pythonidae')

# %%
type(df)
# Out:
# list

# %%
df
# Out:
# [    0                                                  1
#  0 NaN  This article's lead section may be too short t...,
#                                             Pythonidae                                       Pythonidae.1
#  0                                                 NaN                                                NaN
#  1                      Indian python (Python molurus)                     Indian python (Python molurus)
#  2                           Scientific classification                          Scientific classification
#  3                                            Kingdom:                                           Animalia
#  4                                             Phylum:                                           Chordata
#  5                                              Class:                                           Reptilia
#  6                                              Order:                                           Squamata
# ...

# %%
len(df)
# Out:
# 9

# %%
df[2]
# Out:
#             Genus[2]  ...                                Geographic range[1]
# 0          Antaresia  ...             Australia in arid and tropical regions
# 1        Apodora[13]  ...                                   Papua New Guinea
# 2          Aspidites  ...       Australia except in the south of the country
# 3       Bothrochilus  ...                               Bismarck Archipelago
# 4         Leiopython  ...                                   Papua New Guinea
# 5             Liasis  ...  Indonesia in the Lesser Sunda Islands, east th...
# 6       Malayopython  ...                                From India to Timor
# 7            Morelia  ...  From Indonesia in the Maluku Islands, east thr...
# 8   Nyctophilopython  ...                      Northern Territory, Australia
# 9          Python[b]  ...  Africa in the tropics south of the Sahara (not...
# 10           Simalia  ...  Found in Indonesia (Including the islands of H...
#
# [11 rows x 6 columns]

# %%
df2 = pd.read_html('https://money.cnn.com/quote/quote.html?symb=PFE')

# %%
len(df2)
# Out:
# 7

# %%
df2[2]
# Out:
#                            0              1
# 0             Previous close          54.53
# 1               Today’s open          55.79
# 2                Day’s range  55.37 - 56.43
# 3                     Volume       52956422
# 4  Average volume (3 months)       36920953
# 5                 Market cap        $331.4B

# %%
df2[2].tail()
# Out:
#                            0              1
# 1               Today’s open          55.79
# 2                Day’s range  55.37 - 56.43
# 3                     Volume       52956422
# 4  Average volume (3 months)       36920953
# 5                 Market cap        $331.4B
